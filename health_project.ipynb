# %%
# These are the only packages that aren't already on a typical Colab/Kaggle runtime.
# Comment out anything you already have if it slows the kernel down.
# !pip install -q monai kagglehub xgboost shap grad-cam
